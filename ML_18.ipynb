# %%
#use matplotlib.pyplot to show data into plot (use function in data visualization)

import matplotlib.pyplot as plt


x = [1,2,3,4,5,6,7,8,9]

y = [4,7,8,6,5,3,2,9,4] 

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Our first Plot')
plt.show()
